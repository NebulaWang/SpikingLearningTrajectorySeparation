# %%
# import package
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
# Check whether a GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
repeat_index = 27
dat_dir = '/content/drive/MyDrive/Project/PlasticityDecoding/data/FixedRepresentation'
spk = np.load(dat_dir + f'/Spk_an_wn_{repeat_index}.npy')
w = np.load(dat_dir + f'/snn_BDP_w1_{repeat_index}.npy')
tuned_index = np.load(dat_dir + f'/Tune_{repeat_index}.npy')
print(tuned_index)
# Out:
# [  3 145 168 177 178 189 200]

# %%
epoch = 29
plt.figure(dpi=600)
plt.imshow(spk[:, epoch * 500 : (epoch + 1) * 500], cmap='gray_r')
plt.axis('off')
sns.despine()
plt.show()

# %%
repeat_index = 8
dat_dir = '/content/drive/MyDrive/Project/PlasticityDecoding/data/EndtoEnd'
spk = np.load(dat_dir + f'/Spk_an_wn_{repeat_index}.npy')
plt.figure(dpi=600)
plt.imshow(spk[:, 25 * 500 : -1], cmap='gray_r')
plt.axis('off')
plt.title('EndtoEnd')
sns.despine()
plt.show()

# %%
repeat_index = 21
dat_dir = '/content/drive/MyDrive/Project/PlasticityDecoding/data/EndtoEnd01'
spk = np.load(dat_dir + f'/Spk_an_wn_{repeat_index}.npy')
plt.figure(dpi=600)
plt.imshow(spk[:, 25 * 500 : -1], cmap='gray_r')
plt.axis('off')
plt.title('EndtoEnd01')
sns.despine()
plt.show()
