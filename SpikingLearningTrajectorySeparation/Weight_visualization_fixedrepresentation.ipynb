# %%
# import package
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
# Check whether a GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
repeat_index = 27
dat_dir = '/content/drive/MyDrive/Project/PlasticityDecoding/data/FixedRepresentation'
w_STDP = np.load(dat_dir + f'/snn_STDP_w1_{repeat_index}.npy')
w_BDP = np.load(dat_dir + f'/snn_BDP_w1_{repeat_index}.npy')
w_BPTT1 = np.load(dat_dir + f'/snn_BP1_w1_{repeat_index}.npy')
w_BPTT2 = np.load(dat_dir + f'/snn_BP2_w1_{repeat_index}.npy')
w_NC = np.load(dat_dir + f'/snn_NC_w1_{repeat_index}.npy')
tuned_index = np.load(dat_dir + f'/Tune_{repeat_index}.npy')
print(tuned_index)
# Out:
# [  3 145 168 177 178 189 200]

# %%
tune = tuned_index[5]
plt.figure(dpi=200)
plt.imshow(w_STDP[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BDP[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BPTT1[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BPTT2[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_NC[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()

# %%
tune = tuned_index[3]
plt.figure(dpi=200)
plt.imshow(w_STDP[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BDP[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BPTT1[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BPTT2[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_NC[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()

# %%
tune = tuned_index[6]
plt.figure(dpi=200)
plt.imshow(w_STDP[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BDP[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BPTT1[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_BPTT2[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
plt.figure(dpi=200)
plt.imshow(w_NC[:,tune].T.reshape(28,28), cmap='gray_r')
plt.axis('off')
plt.show()
